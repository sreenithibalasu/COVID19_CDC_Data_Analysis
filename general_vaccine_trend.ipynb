# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go

from IPython.display import display
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

# %matplotlib inline

# %%
data_folder = 'data'
vaccines_file = 'COVID-19_Vaccinations_in_the_United_States_Jurisdiction.csv'

# %%
df = pd.read_csv(f'{data_folder}/{vaccines_file}')

# %%
df.head()
# Out:
#          Date  MMWR_week Location  Distributed  Distributed_Janssen  \
# 0  09/28/2022         39      VA2      8845320               626900
# 1  09/28/2022         39       NE      4747440               151900
# 2  09/28/2022         39       DE      2836355               101200
# 3  09/28/2022         39       WV      4821645               170200
# 4  09/28/2022         39       IA      7984855               292500
#
#    Distributed_Moderna  Distributed_Pfizer  Distributed_Novavax  \
# 0              4313180             3898140               7100.0
# 1              1627380             2963760               4400.0
# 2              1078600             1653155               3400.0
# 3              1924920             2719525               7000.0
# 4              3003020             4676835              12500.0
#
#    Distributed_Unk_Manuf  Dist_Per_100K  ...  Second_Booster_65Plus_Vax_Pct  \
# 0                      0              0  ...                           28.5
# 1                      0         245421  ...                           45.6
# 2                      0         291277  ...                           46.7
# 3                      0         269043  ...                           37.8
# 4                      0         253080  ...                           49.3
#
#    Second_Booster_Janssen  Second_Booster_Moderna  Second_Booster_Pfizer  \
# 0                    58.0                152100.0               141364.0
# 1                   114.0                 62272.0               105351.0
# 2                    88.0                 43047.0                52049.0
# 3                    72.0                 57960.0                67207.0
# 4                   100.0                141038.0               170500.0
#
#    Second_Booster_Unk_Manuf  Administered_Bivalent  Admin_Bivalent_PFR  \
# 0                       1.0                    NaN                 NaN
# 1                     342.0                    NaN                 NaN
# 2                      27.0                    NaN                 NaN
# 3                      35.0                    NaN                 NaN
# 4                     139.0                    NaN                 NaN
#
#    Admin_Bivalent_MOD  Dist_Bivalent_PFR  Dist_Bivalent_MOD
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
#
# [5 rows x 101 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
max_admin = max(df['Administered'])
for i in df.index:
    if df.loc[i]['Administered'] == max_admin:
        print(i)
        break
# Out:
# 14

# %%
df.loc[14]
# Out:
# Date                     2022-09-28 00:00:00
# MMWR_week                                 39
# Location                                  US
# Distributed                        854087395
# Distributed_Janssen                 31296200
#                                 ...
# Administered_Bivalent              7570309.0
# Admin_Bivalent_PFR                 4886392.0
# Admin_Bivalent_MOD                 2683917.0
# Dist_Bivalent_PFR                 27024600.0
# Dist_Bivalent_MOD                  9122700.0
# Name: 14, Length: 101, dtype: object

# %% [markdown]
# # Entire US

# %% [markdown]
# # Total Vaccine Doses
#
# - Administered
# - Distributed

# %%
df_usa = df[df['Location'] == 'US'][['Date', 'Location', 'Distributed', 'Administered']]

# %%
df_usa
# Out:
#             Date Location  Distributed  Administered
# 14    2022-09-28       US    854087395     619765972
# 84    2022-09-21       US    843692095     616172308
# 149   2022-09-14       US    834376095     612781120
# 231   2022-09-07       US    817498295     610686563
# 317   2022-08-31       US    809924135     610012616
# ...          ...      ...          ...           ...
# 36193 2020-12-17       US      2847975        127342
# 36272 2020-12-16       US      1656525         51634
# 36353 2020-12-15       US      1458600         12638
# 36418 2020-12-14       US       482625           509
# 36435 2020-12-13       US        13650             0
#
# [566 rows x 4 columns]

# %%
df_usa['Date'].idxmax()
# Out:
# 14

# %% [markdown]
# # As of Sept 29, 2022
#
# ### 854,087,895
# Vaccines have been Distributed
#
# ### 619, 765, 972
# Vaccines have been Administered
#
# *Across the USA

# %%
df_usa.loc[df_usa['Date'].idxmax()]['Administered']
# Out:
# 619765972

# %%
df_usa.loc[df_usa['Date'].idxmax()]['Distributed']
# Out:
# 854087395

# %%
df_usa
# Out:
#             Date Location  Distributed  Administered
# 14    2022-09-28       US    854087395     619765972
# 84    2022-09-21       US    843692095     616172308
# 149   2022-09-14       US    834376095     612781120
# 231   2022-09-07       US    817498295     610686563
# 317   2022-08-31       US    809924135     610012616
# ...          ...      ...          ...           ...
# 36193 2020-12-17       US      2847975        127342
# 36272 2020-12-16       US      1656525         51634
# 36353 2020-12-15       US      1458600         12638
# 36418 2020-12-14       US       482625           509
# 36435 2020-12-13       US        13650             0
#
# [566 rows x 4 columns]

# %% [markdown]
# # USA Vaccine Roll Out

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=df_usa['Date'], y=df_usa['Distributed'], mode='lines', name='USA - Vaccine Rollout over time'))
# Out:
# <div>                            <div id="894fd814-97d6-48c9-9185-fd8a79cdaf80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("894fd814-97d6-48c9-9185-fd8a79cdaf80")) {                    Plotly.newPlot(                        "894fd814-97d6-48c9-9185-fd8a79cdaf80",                        [{"mode":"lines","name":"USA - Vaccine Rollout over time","x":["2022-09-28T00:00:00","2022-09-21T00:00:00","2022-09-14T00:00:00","2022-09-07T00:00:00","2022-08-31T00:00:00","2022-08-24T00:00:00","2022-08-17T00:00:00","2022-08-10T00:00:00","2022-08-03T00:00:00","2022-07-27T00:00:00","2022-07-20T00:00:00","2022-07-13T00:00:00","2022-07-06T00:00:00","2022-06-29T00:00:00","2022-06-22T00:00:00","2022-06-16T00:00:00","2022-06-15T00:00:00","2022-06-14T00:00:00","2022-06-13T00:00:00","2022-06-12T00:00:00","2022-06-11T00:00:00","2022-06-10T00:00:00","2022-06-09T00:00:00","2022-06-08T00:00:00","2022-06-07T00:00:00","2022-06-06T00:00:00","2022-06-05T00:00:00","2022-06-04T00:00:00","2022-06-03T00:00:00","2022-06-02T00:00:00","2022-06-01T00:00:00","2022-05-31T00:00:00","2022-05-30T00:00:00","2022-05-29T00:00:00","2022-05-28T00:00:00","2022-05-27T00:00:00","2022-05-26T00:00:00","2022-05-25T00:00:00","2022-05-24T00:00:00","2022-05-23T00:00:00","2022-05-22T00:00:00","2022-05-21T00:00:00","2022-05-20T00:00:00","2022-05-19T00:00:00","2022-05-18T00:00:00","2022-05-17T00:00:00","2022-05-16T00:00:00","2022-05-15T00:00:00","2022-05-14T00:00:00","2022-05-13T00:00:00","2022-05-12T00:00:00","2022-05-11T00:00:00","2022-05-10T00:00:00","2022-05-09T00:00:00","2022-05-08T00:00:00","2022-05-07T00:00:00","2022-05-06T00:00:00","2022-05-05T00:00:00","2022-05-04T00:00:00","2022-05-03T00:00:00","2022-05-02T00:00:00","2022-05-01T00:00:00","2022-04-30T00:00:00","2022-04-29T00:00:00","2022-04-28T00:00:00","2022-04-27T00:00:00","2022-04-26T00:00:00","2022-04-25T00:00:00","2022-04-24T00:00:00","2022-04-23T00:00:00","2022-04-22T00:00:00","2022-04-21T00:00:00","2022-04-20T00:00:00","2022-04-19T00:00:00","2022-04-18T00:00:00","2022-04-17T00:00:00","2022-04-16T00:00:00","2022-04-15T00:00:00","2022-04-14T00:00:00","2022-04-13T00:00:00","2022-04-12T00:00:00","2022-04-11T00:00:00","2022-04-10T00:00:00","2022-04-09T00:00:00","2022-04-08T00:00:00","2022-04-07T00:00:00","2022-04-06T00:00:00","2022-04-05T00:00:00","2022-04-04T00:00:00","2022-04-03T00:00:00","2022-04-02T00:00:00","2022-04-01T00:00:00","2022-03-31T00:00:00","2022-03-30T00:00:00","2022-03-29T00:00:00","2022-03-28T00:00:00","2022-03-27T00:00:00","2022-03-26T00:00:00","2022-03-25T00:00:00","2022-03-24T00:00:00","2022-03-23T00:00:00","2022-03-22T00:00:00","2022-03-21T00:00:00","2022-03-20T00:00:00","2022-03-19T00:00:00","2022-03-18T00:00:00","2022-03-17T00:00:00","2022-03-16T00:00:00","2022-03-15T00:00:00","2022-03-14T00:00:00","2022-03-13T00:00:00","2022-03-12T00:00:00","2022-03-11T00:00:00","2022-03-10T00:00:00","2022-03-09T00:00:00","2022-03-08T00:00:00","2022-03-07T00:00:00","2022-03-06T00:00:00","2022-03-05T00:00:00","2022-03-04T00:00:00","2022-03-03T00:00:00","2022-03-02T00:00:00","2022-03-01T00:00:00","2022-02-28T00:00:00","2022-02-27T00:00:00","2022-02-26T00:00:00","2022-02-25T00:00:00","2022-02-24T00:00:00","2022-02-23T00:00:00","2022-02-22T00:00:00","2022-02-21T00:00:00","2022-02-20T00:00:00","2022-02-19T00:00:00","2022-02-18T00:00:00","2022-02-17T00:00:00","2022-02-16T00:00:00","2022-02-15T00:00:00","2022-02-14T00:00:00","2022-02-13T00:00:00","2022-02-12T00:00:00","2022-02-11T00:00:00","2022-02-10T00:00:00","2022-02-09T00:00:00","2022-02-08T00:00:00","2022-02-07T00:00:00","2022-02-06T00:00:00","2022-02-05T00:00:00","2022-02-04T00:00:00","2022-02-03T00:00:00","2022-02-02T00:00:00","2022-02-01T00:00:00","2022-01-31T00:00:00","2022-01-30T00:00:00","2022-01-29T00:00:00","2022-01-28T00:00:0 ...

# %%
fig.update_layout(title=f'USA - Vaccine Rollout over time',
                       xaxis_title='Date',
                       yaxis_title='Vaccines Distributed')


fig.update_layout({
'plot_bgcolor': 'rgba(0, 0, 0, 0)',
'paper_bgcolor': 'rgba(0, 0, 0, 0)'},

    title={'y':0.9,
        'x':0.5,'xanchor': 'center',
        'yanchor': 'top'}
)
# Out:
# <div>                            <div id="03538cd9-e62d-4150-8030-d9e8aabf78f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03538cd9-e62d-4150-8030-d9e8aabf78f2")) {                    Plotly.newPlot(                        "03538cd9-e62d-4150-8030-d9e8aabf78f2",                        [{"mode":"lines","name":"USA - Vaccine Rollout over time","x":["2022-09-28T00:00:00","2022-09-21T00:00:00","2022-09-14T00:00:00","2022-09-07T00:00:00","2022-08-31T00:00:00","2022-08-24T00:00:00","2022-08-17T00:00:00","2022-08-10T00:00:00","2022-08-03T00:00:00","2022-07-27T00:00:00","2022-07-20T00:00:00","2022-07-13T00:00:00","2022-07-06T00:00:00","2022-06-29T00:00:00","2022-06-22T00:00:00","2022-06-16T00:00:00","2022-06-15T00:00:00","2022-06-14T00:00:00","2022-06-13T00:00:00","2022-06-12T00:00:00","2022-06-11T00:00:00","2022-06-10T00:00:00","2022-06-09T00:00:00","2022-06-08T00:00:00","2022-06-07T00:00:00","2022-06-06T00:00:00","2022-06-05T00:00:00","2022-06-04T00:00:00","2022-06-03T00:00:00","2022-06-02T00:00:00","2022-06-01T00:00:00","2022-05-31T00:00:00","2022-05-30T00:00:00","2022-05-29T00:00:00","2022-05-28T00:00:00","2022-05-27T00:00:00","2022-05-26T00:00:00","2022-05-25T00:00:00","2022-05-24T00:00:00","2022-05-23T00:00:00","2022-05-22T00:00:00","2022-05-21T00:00:00","2022-05-20T00:00:00","2022-05-19T00:00:00","2022-05-18T00:00:00","2022-05-17T00:00:00","2022-05-16T00:00:00","2022-05-15T00:00:00","2022-05-14T00:00:00","2022-05-13T00:00:00","2022-05-12T00:00:00","2022-05-11T00:00:00","2022-05-10T00:00:00","2022-05-09T00:00:00","2022-05-08T00:00:00","2022-05-07T00:00:00","2022-05-06T00:00:00","2022-05-05T00:00:00","2022-05-04T00:00:00","2022-05-03T00:00:00","2022-05-02T00:00:00","2022-05-01T00:00:00","2022-04-30T00:00:00","2022-04-29T00:00:00","2022-04-28T00:00:00","2022-04-27T00:00:00","2022-04-26T00:00:00","2022-04-25T00:00:00","2022-04-24T00:00:00","2022-04-23T00:00:00","2022-04-22T00:00:00","2022-04-21T00:00:00","2022-04-20T00:00:00","2022-04-19T00:00:00","2022-04-18T00:00:00","2022-04-17T00:00:00","2022-04-16T00:00:00","2022-04-15T00:00:00","2022-04-14T00:00:00","2022-04-13T00:00:00","2022-04-12T00:00:00","2022-04-11T00:00:00","2022-04-10T00:00:00","2022-04-09T00:00:00","2022-04-08T00:00:00","2022-04-07T00:00:00","2022-04-06T00:00:00","2022-04-05T00:00:00","2022-04-04T00:00:00","2022-04-03T00:00:00","2022-04-02T00:00:00","2022-04-01T00:00:00","2022-03-31T00:00:00","2022-03-30T00:00:00","2022-03-29T00:00:00","2022-03-28T00:00:00","2022-03-27T00:00:00","2022-03-26T00:00:00","2022-03-25T00:00:00","2022-03-24T00:00:00","2022-03-23T00:00:00","2022-03-22T00:00:00","2022-03-21T00:00:00","2022-03-20T00:00:00","2022-03-19T00:00:00","2022-03-18T00:00:00","2022-03-17T00:00:00","2022-03-16T00:00:00","2022-03-15T00:00:00","2022-03-14T00:00:00","2022-03-13T00:00:00","2022-03-12T00:00:00","2022-03-11T00:00:00","2022-03-10T00:00:00","2022-03-09T00:00:00","2022-03-08T00:00:00","2022-03-07T00:00:00","2022-03-06T00:00:00","2022-03-05T00:00:00","2022-03-04T00:00:00","2022-03-03T00:00:00","2022-03-02T00:00:00","2022-03-01T00:00:00","2022-02-28T00:00:00","2022-02-27T00:00:00","2022-02-26T00:00:00","2022-02-25T00:00:00","2022-02-24T00:00:00","2022-02-23T00:00:00","2022-02-22T00:00:00","2022-02-21T00:00:00","2022-02-20T00:00:00","2022-02-19T00:00:00","2022-02-18T00:00:00","2022-02-17T00:00:00","2022-02-16T00:00:00","2022-02-15T00:00:00","2022-02-14T00:00:00","2022-02-13T00:00:00","2022-02-12T00:00:00","2022-02-11T00:00:00","2022-02-10T00:00:00","2022-02-09T00:00:00","2022-02-08T00:00:00","2022-02-07T00:00:00","2022-02-06T00:00:00","2022-02-05T00:00:00","2022-02-04T00:00:00","2022-02-03T00:00:00","2022-02-02T00:00:00","2022-02-01T00:00:00","2022-01-31T00:00:00","2022-01-30T00:00:00","2022-01-29T00:00:00","2022-01-28T00:00:0 ...

# %% [markdown]
# # Administered at least one - by Age Category

# %%
df_usa_admin = df[df['Location'] == 'US'][['Date', 'Location', 
                                           'Administered_Dose1_Pop_Pct', 'Administered_Dose1_Recip_5PlusPop_Pct',
                                          'Administered_Dose1_Recip_12PlusPop_Pct', 'Administered_Dose1_Recip_18PlusPop_Pct',
                                          'Administered_Dose1_Recip_65PlusPop_Pct']]

# %%
df_usa_numbers_admin = {'Total': df_usa_admin.loc[df_usa_admin['Date'].idxmax()]['Administered_Dose1_Pop_Pct'], 
                        '5+ Years of Age':  df_usa_admin.loc[df_usa_admin['Date'].idxmax()]['Administered_Dose1_Recip_5PlusPop_Pct'],
                       '12+ Years of Age': df_usa_admin.loc[df_usa_admin['Date'].idxmax()]['Administered_Dose1_Recip_12PlusPop_Pct'],
                       '18+ Years of Age': df_usa_admin.loc[df_usa_admin['Date'].idxmax()]['Administered_Dose1_Recip_18PlusPop_Pct'],
                       '65+ Years of Age': df_usa_admin.loc[df_usa_admin['Date'].idxmax()]['Administered_Dose1_Recip_65PlusPop_Pct']}

# %%
df_usa_numbers_admin
# Out:
# {'Total': 79.5,
#  '5+ Years of Age': 84.1,
#  '12+ Years of Age': 88.7,
#  '18+ Years of Age': 90.5,
#  '65+ Years of Age': 95.0}

# %% [markdown]
# # Completed Full Vaccine Series - by Age Category

# %%
df_usa_series = df[df['Location'] == 'US'][['Date', 'Location', 
                                           'Series_Complete_Pop_Pct', 'Series_Complete_5PlusPop_Pct',
                                          'Series_Complete_12PlusPop_Pct', 'Series_Complete_18PlusPop_Pct',
                                          'Series_Complete_65PlusPop_Pct']]

# %%
df_usa_numbers_series = {'Total': df_usa_series.loc[df_usa_series['Date'].idxmax()]['Series_Complete_Pop_Pct'], 
                        '5+ Years of Age':  df_usa_series.loc[df_usa_series['Date'].idxmax()]['Series_Complete_5PlusPop_Pct'],
                       '12+ Years of Age': df_usa_series.loc[df_usa_series['Date'].idxmax()]['Series_Complete_12PlusPop_Pct'],
                       '18+ Years of Age': df_usa_series.loc[df_usa_series['Date'].idxmax()]['Series_Complete_18PlusPop_Pct'],
                       '65+ Years of Age': df_usa_series.loc[df_usa_series['Date'].idxmax()]['Series_Complete_65PlusPop_Pct']}

# %%
df_usa_numbers_series
# Out:
# {'Total': 67.9,
#  '5+ Years of Age': 72.0,
#  '12+ Years of Age': 76.1,
#  '18+ Years of Age': 77.6,
#  '65+ Years of Age': 92.4}

# %% [markdown]
# # Received First Booster - by Age Category

# %%
df_usa_first_boost = df[df['Location'] == 'US'][['Date', 'Location', 
                                           'Additional_Doses_Vax_Pct', 'Additional_Doses_5Plus_Vax_Pct',
                                          'Additional_Doses_12Plus_Vax_Pct', 'Additional_Doses_18Plus_Vax_Pct',
                                          'Additional_Doses_65Plus_Vax_Pct']]

# %%
df_usa_numbers_booster1 = {'Total': df_usa_first_boost.loc[df_usa_first_boost['Date'].idxmax()]['Additional_Doses_Vax_Pct'], 
                        '5+ Years of Age':  df_usa_first_boost.loc[df_usa_first_boost['Date'].idxmax()]['Additional_Doses_5Plus_Vax_Pct'],
                       '12+ Years of Age': df_usa_first_boost.loc[df_usa_first_boost['Date'].idxmax()]['Additional_Doses_12Plus_Vax_Pct'],
                       '18+ Years of Age': df_usa_first_boost.loc[df_usa_first_boost['Date'].idxmax()]['Additional_Doses_18Plus_Vax_Pct'],
                       '65+ Years of Age': df_usa_first_boost.loc[df_usa_first_boost['Date'].idxmax()]['Additional_Doses_65Plus_Vax_Pct']}

# %%
df_usa_numbers_booster1
# Out:
# {'Total': 48.8,
#  '5+ Years of Age': 48.9,
#  '12+ Years of Age': 50.3,
#  '18+ Years of Age': 51.9,
#  '65+ Years of Age': 71.1}

# %% [markdown]
# # Received Second Booster - by Age Category

# %%
df_usa_second_boost = df[df['Location'] == 'US'][['Date', 'Location', 
                                           'Second_Booster_50Plus_Vax_Pct','Second_Booster_65Plus_Vax_Pct']]

# %%
df_usa_numbers_booster2 = {
                        '50+ Years of Age':  df_usa_second_boost.loc[df_usa_second_boost['Date'].idxmax()]['Second_Booster_50Plus_Vax_Pct'],
                       '65+ Years of Age': df_usa_second_boost.loc[df_usa_second_boost['Date'].idxmax()]['Second_Booster_65Plus_Vax_Pct']}

# %%
df_usa_numbers_booster2
# Out:
# {'50+ Years of Age': 36.6, '65+ Years of Age': 43.8}

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=list(df_usa_numbers_admin.keys())[1:],
                    y=list(df_usa_numbers_admin.values())[1:],
                    name='At least One Dose Received'))
fig.add_trace(go.Bar(x=list(df_usa_numbers_series.keys())[1:],
                    y=list(df_usa_numbers_series.values())[1:],
                    name='Completed Vaccination Series'))

fig.update_layout(title=f'USA - % of Population Vaccinated',
                       xaxis_title='Age Category',
                       yaxis_title='% of Population')


fig.update_layout({
'plot_bgcolor': 'rgba(0, 0, 0, 0)',
'paper_bgcolor': 'rgba(0, 0, 0, 0)'},

    title={'y':0.9,
        'x':0.5,'xanchor': 'center',
        'yanchor': 'top'}
)
# Out:
# <div>                            <div id="eef4ff25-1cb3-48d2-9da8-ffe60303399b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eef4ff25-1cb3-48d2-9da8-ffe60303399b")) {                    Plotly.newPlot(                        "eef4ff25-1cb3-48d2-9da8-ffe60303399b",                        [{"name":"At least One Dose Received","x":["5+ Years of Age","12+ Years of Age","18+ Years of Age","65+ Years of Age"],"y":[84.1,88.7,90.5,95.0],"type":"bar"},{"name":"Completed Vaccination Series","x":["5+ Years of Age","12+ Years of Age","18+ Years of Age","65+ Years of Age"],"y":[72.0,76.1,77.6,92.4],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"c ...

# %% [markdown]
# # Administered vs Distributed - Vaccine Type

# %%
df_vaccine_type_distributed = df[df['Location'] == 'US'][['Date', 'Location', 'Distributed', 'Distributed_Janssen',
                                             'Distributed_Moderna', 'Dist_Bivalent_MOD', 'Distributed_Pfizer', 
                                              'Dist_Bivalent_PFR','Distributed_Novavax','Distributed_Unk_Manuf']]

# %%
df_vaccine_type_distributed
# Out:
#             Date Location  Distributed  Distributed_Janssen  \
# 14    2022-09-28       US    854087395             31296200
# 84    2022-09-21       US    843692095             31272300
# 149   2022-09-14       US    834376095             31244100
# 231   2022-09-07       US    817498295             31217600
# 317   2022-08-31       US    809924135             31195700
# ...          ...      ...          ...                  ...
# 36193 2020-12-17       US      2847975                    0
# 36272 2020-12-16       US      1656525                    0
# 36353 2020-12-15       US      1458600                    0
# 36418 2020-12-14       US       482625                    0
# 36435 2020-12-13       US        13650                    0
#
#        Distributed_Moderna  Dist_Bivalent_MOD  Distributed_Pfizer  \
# 14               313014120          9122700.0           508950075
# 84               309366020          5864600.0           502247675
# 149              307784920                NaN           494574175
# 231              304241820                NaN           481332975
# 317              301794360                NaN           476252575
# ...                    ...                ...                 ...
# 36193                    0                NaN                   0
# 36272                    0                NaN                   0
# 36353                    0                NaN                   0
# 36418                    0                NaN                   0
# 36435                    0                NaN                   0
#
#        Dist_Bivalent_PFR  Distributed_Novavax  Distributed_Unk_Manuf
# 14            27024600.0             827000.0                      0
# 84            21531300.0             806100.0                      0
# 149                  NaN             772900.0                      0
# 231                  NaN             705900.0                      0
# 317                  NaN             681500.0                      0
# ...                  ...                  ...                    ...
# 36193                NaN                  NaN                      0
# 36272                NaN                  NaN                      0
# 36353                NaN                  NaN                      0
# 36418                NaN                  NaN                      0
# 36435                NaN                  NaN                      0
#
# [566 rows x 10 columns]

# %%
numbers_vaccine_type_dist = {'Total Distributed': df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Distributed'],
                            'Pfizer': df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Distributed_Pfizer'],
                            'Pfizer BiValent Booster': df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Dist_Bivalent_PFR'],
                            'Moderna': df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Distributed_Moderna'],
                            'Moderna BiValent Booster':  df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Dist_Bivalent_MOD'],
                            'J&J/Janssen':  df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Distributed_Janssen'],
                            'Novavax':  df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Distributed_Novavax'],
                            'Other':  df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Distributed_Unk_Manuf']}

# %%
numbers_vaccine_type_dist
# Out:
# {'Total Distributed': 854087395,
#  'Pfizer': 508950075,
#  'Pfizer BiValent Booster': 27024600.0,
#  'Moderna': 313014120,
#  'Moderna BiValent Booster': 9122700.0,
#  'J&J/Janssen': 31296200,
#  'Novavax': 827000.0,
#  'Other': 0}

# %%
colors = ['mediumaquamarine', 'mediumseagreen', 'coral', 'darksalmon', 'plum', 'yellow', 'purple']

fig = go.Figure()
fig.add_trace(go.Bar(x=list(numbers_vaccine_type_dist.values())[1:],
             y=list(numbers_vaccine_type_dist.keys())[1:],  orientation='h',
                    marker_color=colors))
# Out:
# <div>                            <div id="e5fd6549-d39c-4555-b069-ee9d9fba137e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5fd6549-d39c-4555-b069-ee9d9fba137e")) {                    Plotly.newPlot(                        "e5fd6549-d39c-4555-b069-ee9d9fba137e",                        [{"marker":{"color":["mediumaquamarine","mediumseagreen","coral","darksalmon","plum","yellow","purple"]},"orientation":"h","x":[508950075,27024600.0,313014120,9122700.0,31296200,827000.0,0],"y":["Pfizer","Pfizer BiValent Booster","Moderna","Moderna BiValent Booster","J&J/Janssen","Novavax","Other"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorb ...
#
# var gd = document.getElementById('e5fd6549-d39c-4555-b069-ee9d9fba137e');
# var x = new MutationObserver(function

# %%
fig.update_layout(yaxis=dict(autorange="reversed"))
fig.update_layout(title=f'USA - COVID-19 Vaccines Distributed by Vaccine Type',
                       xaxis_title='Number of Vaccines Distributed',
                       yaxis_title='Vaccine Type')


fig.update_layout({
'plot_bgcolor': 'rgba(0, 0, 0, 0)',
'paper_bgcolor': 'rgba(0, 0, 0, 0)'},

    title={'y':0.9,
        'x':0.5,'xanchor': 'center',
        'yanchor': 'top'}
)
# Out:
# <div>                            <div id="75a025c2-0037-404a-bba4-f20712ef002b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75a025c2-0037-404a-bba4-f20712ef002b")) {                    Plotly.newPlot(                        "75a025c2-0037-404a-bba4-f20712ef002b",                        [{"marker":{"color":["mediumaquamarine","mediumseagreen","coral","darksalmon","plum","yellow","purple"]},"orientation":"h","x":[508950075,27024600.0,313014120,9122700.0,31296200,827000.0,0],"y":["Pfizer","Pfizer BiValent Booster","Moderna","Moderna BiValent Booster","J&J/Janssen","Novavax","Other"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorb ...

# %%
df_vaccine_type_administered = df[df['Location'] == 'US'][['Date', 'Location', 'Administered', 'Administered_Janssen',
                                             'Administered_Moderna', 'Admin_Bivalent_MOD', 'Administered_Pfizer', 
                                              'Admin_Bivalent_PFR','Administered_Novavax','Administered_Unk_Manuf']]

# %%
numbers_vaccine_type_administered = {'Total Administered': df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Administered'],
                            'Pfizer': df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Administered_Pfizer'],
                            'Pfizer BiValent Booster': df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Admin_Bivalent_PFR'],
                            'Moderna': df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Administered_Moderna'],
                            'Moderna BiValent Booster':  df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Admin_Bivalent_MOD'],
                            'J&J/Janssen':  df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Administered_Janssen'],
                            'Novavax':  df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Administered_Novavax'],
                            'Other':  df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Administered_Unk_Manuf']}

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x=list(numbers_vaccine_type_administered.values())[1:],
             y=list(numbers_vaccine_type_administered.keys())[1:],  orientation='h',
                    marker_color=colors))
# Out:
# <div>                            <div id="0e58386b-7f5d-4bdb-978f-d073064cde23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e58386b-7f5d-4bdb-978f-d073064cde23")) {                    Plotly.newPlot(                        "0e58386b-7f5d-4bdb-978f-d073064cde23",                        [{"marker":{"color":["mediumaquamarine","mediumseagreen","coral","darksalmon","plum","yellow","purple"]},"orientation":"h","x":[367217199,4886392.0,232943541,2683917.0,18902992,30261.0,671979],"y":["Pfizer","Pfizer BiValent Booster","Moderna","Moderna BiValent Booster","J&J/Janssen","Novavax","Other"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"col ...
#
# var gd = document.getElementById('0e58386b-7f5d-4bdb-978f-d073064cde23');
# var x = new MutationObserver(functi

# %%
fig.update_layout(yaxis=dict(autorange="reversed"))
fig.update_layout(title=f'USA - COVID-19 Vaccines Administered by Vaccine Type',
                       xaxis_title='Number of Vaccines Administered',
                       yaxis_title='Vaccine Type')


fig.update_layout({
'plot_bgcolor': 'rgba(0, 0, 0, 0)',
'paper_bgcolor': 'rgba(0, 0, 0, 0)'},

    title={'y':0.9,
        'x':0.5,'xanchor': 'center',
        'yanchor': 'top'}
)
# Out:
# <div>                            <div id="d789c1d4-2c98-44c0-912a-719756198dd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d789c1d4-2c98-44c0-912a-719756198dd9")) {                    Plotly.newPlot(                        "d789c1d4-2c98-44c0-912a-719756198dd9",                        [{"marker":{"color":["mediumaquamarine","mediumseagreen","coral","darksalmon","plum","yellow","purple"]},"orientation":"h","x":[367217199,4886392.0,232943541,2683917.0,18902992,30261.0,671979],"y":["Pfizer","Pfizer BiValent Booster","Moderna","Moderna BiValent Booster","J&J/Janssen","Novavax","Other"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"col ...

# %%
@widgets.interact(Location=df['Location'].sort_values().unique())
def plot_dist_by_location(Location):
    df_vaccine_type_distributed = df[df['Location'] == Location][['Date', 'Location', 'Distributed', 'Distributed_Janssen',
                                             'Distributed_Moderna', 'Dist_Bivalent_MOD', 'Distributed_Pfizer', 
                                              'Dist_Bivalent_PFR','Distributed_Novavax','Distributed_Unk_Manuf']]
    
    numbers_vaccine_type_dist = {'Total Distributed': df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Distributed'],
                            'Pfizer': df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Distributed_Pfizer'],
                            'Pfizer BiValent Booster': df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Dist_Bivalent_PFR'],
                            'Moderna': df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Distributed_Moderna'],
                            'Moderna BiValent Booster':  df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Dist_Bivalent_MOD'],
                            'J&J/Janssen':  df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Distributed_Janssen'],
                            'Novavax':  df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Distributed_Novavax'],
                            'Other':  df_vaccine_type_distributed.loc[df_vaccine_type_distributed['Date'].idxmax()]['Distributed_Unk_Manuf']}
    fig = go.Figure()
    fig.add_trace(go.Bar(x=list(numbers_vaccine_type_dist.values())[1:],
                 y=list(numbers_vaccine_type_dist.keys())[1:],  orientation='h',
                        marker_color=colors))
    
    fig.update_layout(yaxis=dict(autorange="reversed"))
    fig.update_layout(title=f'{Location} - COVID-19 Vaccines Distributed by Vaccine Type',
                           xaxis_title='Number of Vaccines Distributed',
                           yaxis_title='Vaccine Type')


    fig.update_layout({
    'plot_bgcolor': 'rgba(0, 0, 0, 0)',
    'paper_bgcolor': 'rgba(0, 0, 0, 0)'},

        title={'y':0.9,
            'x':0.5,'xanchor': 'center',
            'yanchor': 'top'}
    )
    fig.show()
# Out:
# interactive(children=(Dropdown(description='Location', options=('AK', 'AL', 'AR', 'AS', 'AZ', 'BP2', 'CA', 'CO…

# %%
@widgets.interact(Location=df['Location'].sort_values().unique())
def plot_admin_by_location(Location):
    df_vaccine_type_administered = df[df['Location'] == Location][['Date', 'Location', 'Administered', 'Administered_Janssen',
                                             'Administered_Moderna', 'Admin_Bivalent_MOD', 'Administered_Pfizer', 
                                              'Admin_Bivalent_PFR','Administered_Novavax','Administered_Unk_Manuf']]
    
    numbers_vaccine_type_administered = {'Total Administered': df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Administered'],
                            'Pfizer': df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Administered_Pfizer'],
                            'Pfizer BiValent Booster': df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Admin_Bivalent_PFR'],
                            'Moderna': df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Administered_Moderna'],
                            'Moderna BiValent Booster':  df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Admin_Bivalent_MOD'],
                            'J&J/Janssen':  df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Administered_Janssen'],
                            'Novavax':  df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Administered_Novavax'],
                            'Other':  df_vaccine_type_administered.loc[df_vaccine_type_administered['Date'].idxmax()]['Administered_Unk_Manuf']}
    
    fig = go.Figure()
    fig.add_trace(go.Bar(x=list(numbers_vaccine_type_administered.values())[1:],
                 y=list(numbers_vaccine_type_administered.keys())[1:],  orientation='h',
                        marker_color=colors))
    
    fig.update_layout(yaxis=dict(autorange="reversed"))
    fig.update_layout(title=f'{Location} - COVID-19 Vaccines Administered by Vaccine Type',
                           xaxis_title='Number of Vaccines Administered',
                           yaxis_title='Vaccine Type')


    fig.update_layout({
    'plot_bgcolor': 'rgba(0, 0, 0, 0)',
    'paper_bgcolor': 'rgba(0, 0, 0, 0)'},

        title={'y':0.9,
            'x':0.5,'xanchor': 'center',
            'yanchor': 'top'}
    )
    fig.show()
# Out:
# interactive(children=(Dropdown(description='Location', options=('AK', 'AL', 'AR', 'AS', 'AZ', 'BP2', 'CA', 'CO…
